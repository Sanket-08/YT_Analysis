# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyBKOLyVAk42Kyw-eNqQL8nzRfuQ-qXd-Zc'
channel_ids = ['UCRj_BU95SebaRi2FziXEoTg', # RakaZone Gaming 
               'UCq2f2CXdCL7A0tGQ_yiDQlA', # TbOne 
               'UCPovnM0KxuyPOedwiDFsvOA', # Fa2
               'UCcz2rzroRCKuR0pi6Oj-SbQ', # Mili kya Mili 
               'UCH4YXG1SMJQsbG8T8gK42Lg' # Ankkita C
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#       Channel_name Subscribers     Views Total_videos  \
# 0    Mili kya Mili      243000  21818065          892
# 1  RakaZone Gaming      481000  46062283          393
# 2        Ankkita C      350000  34767904          538
# 3            TbOne      209000  27368477          238
# 4              fa2      131000  38973314         1012
#
#                 playlist_id
# 0  UUcz2rzroRCKuR0pi6Oj-SbQ
# 1  UURj_BU95SebaRi2FziXEoTg
# 2  UUH4YXG1SMJQsbG8T8gK42Lg
# 3  UUq2f2CXdCL7A0tGQ_yiDQlA
# 4  UUPovnM0KxuyPOedwiDFsvOA

# %% [markdown]
# ### Changing the Datatypes

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# ### Function to get video ids

# %%
channel_data
# Out:
#       Channel_name  Subscribers     Views  Total_videos  \
# 0    Mili kya Mili       243000  21818065           892
# 1  RakaZone Gaming       481000  46062283           393
# 2        Ankkita C       350000  34767904           538
# 3            TbOne       209000  27368477           238
# 4              fa2       131000  38973314          1012
#
#                 playlist_id
# 0  UUcz2rzroRCKuR0pi6Oj-SbQ
# 1  UURj_BU95SebaRi2FziXEoTg
# 2  UUH4YXG1SMJQsbG8T8gK42Lg
# 3  UUq2f2CXdCL7A0tGQ_yiDQlA
# 4  UUPovnM0KxuyPOedwiDFsvOA

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='RakaZone Gaming', 'playlist_id'].iloc[0]

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['98SXUUuzKaI',
#  'WtUBAUl_fog',
#  '54UPgxlQLEM',
#  'PIyoJfm07D4',
#  'yKb-DVUUITs',
#  'CwOnQDmWvQY',
#  'ZPTF2yZFd04',
#  'vFsSWObKoJs',
#  'Y1VpOJ_VD0U',
#  'jw3lSIEXrhw',
#  'SxMjueE2Iv4',
#  '55LjFfR_M5E',
#  'N3ZCtkAqQ_s',
#  'SAlEqL5i7jQ',
#  '6rWE3eGu7pk',
#  'HxI9ZAdyLZM',
#  'ZFKHZVERzr8',
#  'B1fOIohyz7Y',
#  'adbAmumebZo',
#  'vbxOwKCn5iA',
#  'e5FCPX0bkvo',
#  'ZNIG11laSN4',
#  'XFiM21F9OYE',
#  'o_zJNMLKG64',
#  '0W6AwZgAeSA',
#  '9_9YaJEvMz8',
#  'A2vUuoBK7zk',
#  'h7C4q7ui7zo',
#  'sWqDqqaCgyc',
#  'IpPxJRyYDJ4',
#  '-Cp6b6ZX1PI',
#  'LTFwEQpgKPA',
#  '0UsgYwNpBLo',
#  'hujMCSpxpnA',
#  '2z1ulCSKrik',
#  'cdZHqUmLmdU',
#  'XoULki49Hmw',
#  'FFeHvIBoX0Q',
#  'CkU3e6B-Mwo',
#  'erks5zmcEcI',
#  'XNvP3oG-_CE',
#  'PnlX2maInWE',
#  'd_388J8wcKg',
#  '6aP1FGq7CbA',
#  'miUSfVRlG_0',
#  'tORnhRH0q0k',
#  '5DZz6m7eDbs',
#  'Pil8XuW6X74',
#  'm_XML5CXCm0',
#  '3dYll16qzm8',
#  'TyBP7QNh4WA',
#  'DqmrBUjCaik',
#  'aokcjZSMAEE',
#  'lKntYobiM0w',
#  'PEM_MDANeFo',
# ...

# %% [markdown]
# ### Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Comments = video['statistics']['commentCount']
                               )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0                 Making Huge Profit From Case Opening     2022-11-06   46678
# 1    Mr. Marlega - The Untold Story Finale | Casino...     2022-11-04   79571
# 2    India vs Bangladesh Full Match Highlights Hind...     2022-11-02  105667
# 3    Call of Duty Modern Warfare 2 Full Game | Live...     2022-11-02  101383
# 4                    When GIRLS Comment on your VIDEOS     2022-11-01   40136
# ..                                                 ...            ...     ...
# 388  Modern Warfare Remastered Sniping Challenge • ...     2016-11-15    5474
# 389  Top 10 Ninja Defuse in Call Of Duty Black Ops ...     2016-09-21     814
# 390  Killed Him 6 Times In A Row • Black Ops 3 Sniping     2016-09-18     816
# 391  Call of Duty Black Ops 3 My Best Sniper Montag...     2016-03-11    4381
# 392  Call of Duty Black Ops 3 Best Assualt Rifle SH...     2016-02-29   20920
#
#      Likes Comments
# ...

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 266  How To Download Call Of Duty Warzone For FREE ...     2020-03-12
# 270  We Entered A Haunted House Ft. Carryminati, Ga...     2020-02-22
# 316  NDTV Gadgets 360 Interview Ft  Dynamo Gaming, ...     2019-05-24
# 302             RakaZone Gaming got Banned in GTA 5 RP     2019-08-24
# 309  CSGO Funny Moments With Carryminati, Gareeb, G...     2019-07-13
# 301  How Indians Play GTA 5 • GTA 5 Funny Moments &...     2019-08-31
# 317  CSGO Funny Moments With Carryminati, Gunshot, ...     2019-05-11
# 299  GTA 5 Role Play In Indian Legacy Servers • GTA...     2019-09-08
# 163         This is Why Mumbai Indians win IPL seasons     2021-05-02
# 297  GTA 5 Role Play In Indian Legacy Servers • GTA...     2019-09-16
#
#        Views  Likes Comments
# 266  1200045  27569     1366
# 270   894073  33510      420
# 316   737385  32628     1647
# 302   617505  26340      483
# 309   583128  24784      328
# ...

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)

# %%
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0                 Making Huge Profit From Case Opening     2022-11-06   46678
# 1    Mr. Marlega - The Untold Story Finale | Casino...     2022-11-04   79571
# 2    India vs Bangladesh Full Match Highlights Hind...     2022-11-02  105667
# 3    Call of Duty Modern Warfare 2 Full Game | Live...     2022-11-02  101383
# 4                    When GIRLS Comment on your VIDEOS     2022-11-01   40136
# ..                                                 ...            ...     ...
# 388  Modern Warfare Remastered Sniping Challenge • ...     2016-11-15    5474
# 389  Top 10 Ninja Defuse in Call Of Duty Black Ops ...     2016-09-21     814
# 390  Killed Him 6 Times In A Row • Black Ops 3 Sniping     2016-09-18     816
# 391  Call of Duty Black Ops 3 My Best Sniper Montag...     2016-03-11    4381
# 392  Call of Duty Black Ops 3 Best Assualt Rifle SH...     2016-02-29   20920
#
#      Likes Comments
# ...

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0                 Making Huge Profit From Case Opening     2022-11-06   46678
# 1    Mr. Marlega - The Untold Story Finale | Casino...     2022-11-04   79571
# 2    India vs Bangladesh Full Match Highlights Hind...     2022-11-02  105667
# 3    Call of Duty Modern Warfare 2 Full Game | Live...     2022-11-02  101383
# 4                    When GIRLS Comment on your VIDEOS     2022-11-01   40136
# ..                                                 ...            ...     ...
# 388  Modern Warfare Remastered Sniping Challenge • ...     2016-11-15    5474
# 389  Top 10 Ninja Defuse in Call Of Duty Black Ops ...     2016-09-21     814
# 390  Killed Him 6 Times In A Row • Black Ops 3 Sniping     2016-09-18     816
# 391  Call of Duty Black Ops 3 My Best Sniper Montag...     2016-03-11    4381
# 392  Call of Duty Black Ops 3 Best Assualt Rifle SH...     2016-02-29   20920
#
#      Likes Comments Month
# ...

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    28
# 1    Aug    30
# 2    Dec    32
# 3    Feb    29
# 4    Jan    20
# 5    Jul    24
# 6    Jun    30
# 7    Mar    29
# 8    May    30
# 9    Nov    44
# 10   Oct    56
# 11   Sep    41

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
             'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()

# %%
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
video_data.to_csv('Video_Details(RakaZone).csv')
